# %%
import pandas as pd
from pandas import Series
import numpy as np

fandango = pd.read_csv('fandango_score_comparison.csv')
fandango = pd.read_csv('fandango_score_comparison.csv')

#print(fandango.index)

series_film = fandango['FILM']
series_rt = fandango['RottenTomatoes']

film_names = series_film.values
rt_scores = series_rt.values
series_custom = Series(rt_scores , index=film_names)

#check rows with index 
series_custom[['Minions (2015)', 'Leviathan (2014)']]
fiveten = series_custom[5:11]

#sort values in different ways by index (movie names) or values (rating)
#1
original_index = series_custom.index
sorted_by_index = series_custom.reindex(sorted(original_index))

#2
sc2 = series_custom.sort_index()
sc3 = series_custom.sort_values()

#normalize the rating 

series_normalized = series_custom/20

#select only tbe movies that meets this creteria 
criteria_one = series_custom > 50
criteria_two = series_custom < 75

both_criteria = series_custom[criteria_one & criteria_two]

#calculate the  mean rating 
rt_critics = Series(fandango['RottenTomatoes'].values, index=fandango['FILM'])
rt_users = Series(fandango['RottenTomatoes_User'].values, index=fandango['FILM'])

rt_mean = (rt_critics + rt_users)/2

# %%
#Return a DF with first and last rows 
first_last = fandango.iloc[[0,len(fandango)-1]]

#new DF: set FILM column as index
fandango_films = fandango.set_index('FILM', drop = False, inplace = False)

#Select only specific rows (movies)
movies = ["The Lazarus Effect (2015)", "Gett: The Trial of Viviane Amsalem (2015)", "Mr. Holmes (2015)"]
best_movies_ever = fandango_films.loc[movies]

# returns the data types as a Series
types = fandango_films.dtypes
# filter data types to just floats, index attributes returns just column names
float_columns = types[types.values == 'float64'].index

# use bracket notation to filter columns to just float columns
float_df = fandango_films[float_columns]
#rating_df = fandango_films[rtcrt,rtusr]

# `x` is a Series object representing a column
deviations = float_df.apply(lambda x: np.std(x))
mean = rating_df.apply(lambda x: np.mean(x))

#Lambda function calculations
double_df = float_df.apply(lambda x: x*2)
halved_df = float_df.apply(lambda x: x/2)

#Calculate average of each movie's values for certain columns
rt_mt_user = float_df[['RT_user_norm', 'Metacritic_user_nom']]
#rt_mt_means = rating_df[['RottenTomatoes', 'RottenTomatoes_User']]

rt_mt_deviations = rt_mt_user.apply(lambda x: np.std(x), axis=1)
#rt_mt_means = rt_mt_means.apply(lambda x: np.mean(x), axis=1)

#print(rt_mt_means[0:5])

# %%
fandango_films.head(1)
# Out:
#                                                           FILM  \
# FILM
# Avengers: Age of Ultron (2015)  Avengers: Age of Ultron (2015)
#
#                                 RottenTomatoes  RottenTomatoes_User  \
# FILM
# Avengers: Age of Ultron (2015)              74                   86
#
#                                 Metacritic  Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)          66              7.1   7.8
#
#                                 Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Avengers: Age of Ultron (2015)             5.0                   4.5      3.7
#
#                                 RT_user_norm         ...           IMDB_norm  \
# FILM                                                 ...
# Avengers: Age of Ultron (2015)           4.3         ...                 3.9
#
#                                 RT_norm_round  RT_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)            3.5                 4.5
#
# ...
